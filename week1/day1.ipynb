# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ## Your first Frontier LLM Project
#
# Let's build a useful LLM solution - in a matter of minutes.
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup for [PC](../SETUP-PC.md) or [Mac](../SETUP-mac.md) and you hopefully launched this jupyter lab from within the project root directory, with your environment activated.
#
# ## If you're new to Jupyter Lab
#
# Welcome to the wonderful world of Data Science experimentation! Once you've used Jupyter Lab, you'll wonder how you ever lived without it. Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. As you wish, you can add a cell with the + button in the toolbar, and print values of variables, or try out variations.
#
# I've written a notebook called [Guide to Jupyter](Guide%20to%20Jupyter.ipynb) to help you get more familiar with Jupyter Labs, including adding Markdown comments, using `!` to run shell commands, and `tqdm` to show progress.
#
# ## If you're new to the Command Line
#
# Please see these excellent guides: [Command line on PC](https://chatgpt.com/share/67b0acea-ba38-8012-9c34-7a2541052665) and [Command line on Mac](https://chatgpt.com/canvas/shared/67b0b10c93a081918210723867525d2b).
#
# ## If you'd prefer to work in IDEs
#
# If you're more comfortable in IDEs like VSCode, Cursor or PyCharm, they both work great with these lab notebooks too.
# If you'd prefer to work in VSCode, [here](https://chatgpt.com/share/676f2e19-c228-8012-9911-6ca42f8ed766) are instructions from an AI friend on how to configure it for the course.
#
# ## If you'd like to brush up your Python
#
# I've added a notebook called [Intermediate Python](Intermediate%20Python.ipynb) to get you up to speed. But you should give it a miss if you already have a good idea what this code does:
# `yield from {book.get("author") for book in books if book.get("author")}`
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X/Twitter at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](troubleshooting.ipynb) notebook in this folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## For foundational technical knowledge (eg Git, APIs, debugging)
#
# If you're relatively new to programming -- I've got your back! While it's ideal to have some programming experience for this course, there's only one mandatory prerequisite: plenty of patience. 😁 I've put together a set of self-study guides that cover Git and GitHub, APIs and endpoints, beginner python and more.
#
# This covers Git and GitHub; what they are, the difference, and how to use them:
# https://github.com/ed-donner/agents/blob/main/guides/03_git_and_github.ipynb
#
# This covers technical foundations:
# ChatGPT vs API; taking screenshots; Environment Variables; Networking basics; APIs and endpoints:
# https://github.com/ed-donner/agents/blob/main/guides/04_technical_foundations.ipynb
#
# This covers Python for beginners, and making sure that a `NameError` never trips you up:
# https://github.com/ed-donner/agents/blob/main/guides/06_python_foundations.ipynb
#
# This covers the essential techniques for figuring out errors:
# https://github.com/ed-donner/agents/blob/main/guides/08_debugging.ipynb
#
# And you'll find other useful guides in the same folder in GitHub. Some information applies to my other Udemy course (eg Async Python) but most of it is very relevant for LLM engineering.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress. Ultimately we will fine-tune our own LLM to compete with OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">This code is a live resource - keep an eye out for my emails</h2>
#             <span style="color:#f71;">I push updates to the code regularly. As people ask questions, I add more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but I've also added better explanations and new models like DeepSeek. Consider this like an interactive book.<br/><br/>
#                 I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI (or Ollama)
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# If you'd like to use free Ollama instead, please see the README section "Free Alternative to Paid APIs", and if you're not sure how to do this, there's a full solution in the solutions folder (day1_with_ollama.ipynb).
#
# ## Troubleshooting if you have problems:
#
# Head over to the [troubleshooting](troubleshooting.ipynb) notebook in this folder for step by step code to identify the root cause and fix it!
#
# If you make a change, try restarting the "Kernel" (the python process sitting behind this notebook) by Kernel menu >> Restart Kernel and Clear Outputs of All Cells. Then try this notebook again, starting at the top.
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# If this doesn't work, try Kernel menu >> Restart Kernel and Clear Outputs Of All Cells, then run the cells from the top of this notebook down.
# If it STILL doesn't work (horrors!) then please see the Troubleshooting notebook in this folder for full instructions

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="gpt-4.1-nano", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! 😊 I'm so glad you reached out. Welcome, and I'm here to help with anything you need. How's your day going?

# %% [markdown]
# ## OK onwards with our first project

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out. Change the website and add print statements to follow along.

ed = Website("https://jdsports.gr")
print(ed.title)
print(ed.text)
# Out:
# JDSports.gr | No1 Προορισμός στην Ελλάδα για Premium Sports και Street Fashion
# My Account ( Login/Signup )
# Καταστήματα
# Βοήθεια
# Πορεία Παραγγελίας
# Αγαπημένα
# Παράδοση σε...
# EL
# EN
# EL
# New In
# Ανδρικά
# Γυναικεία
# Παιδικά
# Αξεσουάρ
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Άνδρας
# Παπούτσια
# New In
# Sneakers
# Slides & Σανδάλια
# Μποτάκια
# Running
# Όλα τα Παπούτσια
# Ρούχα
# New In
# T-shirts & Αμάνικα
# Σορτς & Βερμούδες
# Μαγιό
# Φόρμες & Σετ
# Ζακέτες
# Φούτερ
# Jeans & Cargo Pants
# Μπουφάν
# Όλα τα Ρούχα
# Top Brands
# Nike
# adidas
# Jordan
# Hoodrich
# The North Face
# EA7 Emporio Armani
# New Balance
# McKenzie
# Supply & Demand
# Converse
# Columbia
# Όλα τα brands
# Edits
# 2 T-shirts for 40€
# 2 McKenzie T-shirts for 20€
# Ποδοσφαιρικές Φανέλες
# Graphic Tees
# JD Exclusives
# Λευκά Παπούτσια
# Μαύρα Παπούτσια
# Όλα τα Ανδρικά
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Γυναίκα
# Παπούτσια
# New In
# Sneakers
# Slides & Σανδάλια
# Μποτάκια
# Running
# Γυμναστήριο & Crossfit
# Όλα τα παπούτσια
# Ρούχα
# New In
# T-shirts & Αμάνικα
# Σορτς & Βερμούδες
# Κολάν
# Μπουστάκια
# Μαγιό
# Φόρμες & Σετ
# Φούτερ
# Ζακέτες
# Jeans & Cargo Pants
# Μπουφάν
# Όλα τα Ρούχα
# Top Brands
# Nike
# adidas
# Jordan
# Hoodrich
# New Balance
# The North Face
# Unlike Humans
# UGG
# Converse
# Vans
# PUMA
# Ολα τα brands
# Edits
# JD Exclusives
# Ποδοσφαιρικές Φανέλες
# Graphic Tees
# Λευκά Παπούτσια
# Μαύρα Παπούτσια
# Animal Print
# Gymwear
# Co-Ord Sets
# Όλα τα Γυναικεία
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Παιδί
# Παπούτσια
# New In
# Βρεφικά | No. 19-27
# Παιδικά | No. 28-35
# Εφηβικά | No. 36-40
# Sneakers
# Slides & Σανδάλια
# Μποτάκια
# Running
# Όλα τα Παπούτσια
# Ρούχα
# New In
# T-shirts
# Σορτς & Βερμούδες
# Φόρμες & Σετ Φόρμας
# Μαγιό
# Ζακέτες
# Φούτερ
# Μπουφάν
# Όλα τα Ρούχα
# Αξεσουάρ
# Σακίδια Πλάτης
# Κάλτσες
# Εσώρουχα
# Καπέλα
# Όλα τα Αξεσουαρ
# Ρούχα για Αγόρια
# T-shirts
# Σορτς
# Φόρμες & Σετ Φόρμας
# Ζακέτες
# Φούτερ
# Μπουφάν
# Όλα τα Ρούχα για Αγόρια
# Ρούχα για Κορίτσια
# T-shirts
# Φόρμες & Σετ Φόρμας
# Κολάν
# Φούτερ
# Όλα τα Ρούχα για Κορίτσια
# Top Brands
# Nike
# adidas
# Hoodrich
# Jordan
# Supply & Demand
# McKenzie
# The North Face
# PUMA
# Όλα τα brands
# Edits
# Ποδοσφαιρικές Φανέλες
# JD Exclusives
# Μαύρα Παπούτσια
# Λευκά Παπούτσια
# Best Sellers
# Όλα τα Παιδικά
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Αξεσουάρ
# Ανδρικά
# Kαπέλα
# Κάλτσες
# Τσάντες & Backpacks
# Τσαντάκια
# Εσώρουχα
# Όλα τα Ανδρικά Αξεσουάρ
# Γυναικεία
# Κάλτσες
# Τσάντες & Backpacks
# Kαπέλα
# Φροντίδα Παπουτσιών
# Όλα τα Γυναικεία Αξεσουάρ
# Παιδικά
# Τσάντες & Σχολικά σακίδια
# Φροντίδα Παπουτσιών
# Μπάλες
# Όλα τα Παιδικά Αξεσουάρ
# Top Brands
# Nike
# adidas
# Jordan
# Hoodrich
# Crep Protect
# DFNS
# Calvin Klein
# New Era
# Under Armour
# Όλα τα Brands
# Όλα τα Αξεσουάρ
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Brands
# TOP BRANDS
# adidas
# ASICS
# Birkenstock
# Calvin Klein
# Columbia
# Converse
# CREP Protect
# Crocs
# Daily SZN
# DFNS
# EA7 Emporio Armani
# FILA
# Hoka
# Hoodrich
# Jordan
# Lacoste
# Levi's
# McKenzie
# New Balance
# New Era
# Nike
# On
# Pink Soda Sport
# PUMA
# Reebok
# Salomon
# Supply & Demand
# The North Face
# Timberland
# UGG
# Under Armour
# Unlike Humans
# Vans
# Zavetti
# Όλα τα Brands
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Collections
# Nike
# Nike Shox TL
# Nike Vapormax
# Nike Tech Fleece
# Nike Dunk
# Nike Cortez
# Nike P-6000
# Nike Pro
# Nike Vomero 5
# Nike React Vision
# Nike Blazer
# Nike Gamma Force
# Nike V2K Run
# Nike Pegasus
# Nike Huarache
# Nike Air
# Nike Air Force 1
# Nike Air Max
# Nike Air Max 95
# Nike Air Max Dn
# Nike Air Max Dn8
# Nike Air Max 97
# Nike Air Max 270
# Nike Air Max 90
# Nike Air Max TW
# Nike Air Max Pulse
# Nike Air Max 1
# Nike Air More Uptempo
# adidas
# adidas Campus 00s
# adidas Samba
# adidas Gazelle
# adidas Gazelle Bold
# adidas Spezial
# adidas SL 72
# adidas Climacool
# adidas Megaride
# adidas Drop Step
# adidas Ozweego
# adidas ZX
# adidas Superstar
# adidas Forum
# adidas Stan Smith
# adidas NMD
# adidas Response CL
# adidas Adilette
# New Balance
# New Balance 530
# New Balance 9060
# New Balance 1000
# New Balance 740
# New Balance 1906R
# New Balance 2002R
# New Balance 327
# New Balance 550
# Jordan
# Air Jordan 1
# Jordan Diamond
# Jordan Air
# Jordan Air Legacy 312
# Jordan Brooklyn
# Crocs
# Crocs Classic Clog
# Crocs Mega Crush
# Crocs Bae Clog
# Crocs Bubble Crush Clog
# Crocs Echo
# Converse
# Converse All Star
# Converse Chuck Taylor
# Converse Run Star Legacy CX
# Converse Cruise
# Converse Chuck Taylor All Star Move
# Converse Run Star Hike
# Converse Chuck 70
# Converse All Star Δίπατα
# Converse All Star High Tops
# ASICS
# ASICS Gel
# ASICS Gel-1130
# Birkenstock
# Birkenstock Arizona
# Vans
# Vans Old Skool
# Vans Sk8-Hi
# PUMA
# PUMA Palermo
# PUMA RS
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Savings
# Sale
# Outlet
# Smart Buys
# Όλες οι Ευκαιρίες
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# eGiftcard
# Πληροφορίες
# Follow Us
# Αναζήτηση
# Trending Now
# >
# Trending Now
# Nike Air Force 1
# JD Exclusive
# Χμμ..  Δεν καταφέραμε να βρούμε αποτελέσματα :/
# Δοκίμασε ξανά! Έλεγξε για λάθη πληκτρολόγησης  (ονομασία ή κωδικό προϊόντος)
# Άδειο Καλάθι
# Κανένα προϊόν
# Δωρεάν Μεταφορικά
# Δωρεάν παραλαβή απο κατάστημα
# Δωρεάν μεταφορικά άνω των 69€
# subtotalVar
# Subtotal
# discountVar
# Έκπτωση
# 0
# Σύνολο
# Ολοκλήρωση Αγοράς
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Shop Now
# Shop Now
# Shop Now
# Shop Now
# Αγαπημένα Brands
# ΑΝΔΡΙΚΑ
# Ρούχα
# Παπούτσια
# JD Exclusives
# ΓΥΝΑΙΚΕΙΑ
# Ρούχα
# Παπούτσια
# JD Exclusives
# ΠΑΙΔΙΚΑ
# Ρούχα
# Παπούτσια
# JD Exclusives
# Complete The Look
# T-shirts
# Σορτς
# Slides & Σανδάλια
# JUST DROPPED
# ONLY AT
# Hoodrich Galaxy Ανδρικό T-shirt
# €45.00
# JUST DROPPED
# ONLY AT
# Jordan Flight MVP Ανδρικό T-shirt
# €39.99
# JUST DROPPED
# ONLY AT
# adidas Originals Football Ανδρικό T-shirt
# €40.00
# JUST DROPPED
# ONLY AT
# adidas Originals Classic Γυναικείο T-Shirt
# €35.00
# JUST DROPPED
# ONLY AT
# The North Face Energy Γυναικείο T-Shirt
# €40.00
# JUST DROPPED
# Nike Sportswear Essential Γυναικείο T-Shirt
# €34.99
# JUST DROPPED
# ONLY AT
# The North Face Reflective Grid Παιδικό T-shirt
# €30.00
# Nike Boxy Essential Παιδικό T-shirt
# €22.99
# JUST DROPPED
# Nike Training Pro Γυναικείο Σορτς
# €29.99
# JUST DROPPED
# ONLY AT
# adidas Originals Football Γυναικείο Σορτς
# €40.00
# Jordan Diamond Ανδρικό Σορτς
# €49.99
# JUST DROPPED
# ONLY AT
# The North Face 24/7   Ανδρικό Σορτς
# €45.00
# JUST DROPPED
# ONLY AT
# Hoodrich Erupt Γυναικείο Σορτς
# €40.00
# JUST DROPPED
# ONLY AT
# Hoodrich Legacy Ανδρικό Σορτς
# €60.00
# JUST DROPPED
# Nike Pro Παιδικό Σορτς
# €21.50
# ONLY AT
# McKenzie Racer Παιδικό Σορτς
# €16.00
# Crocs Mega Crush Clog Γυναικεία Σανδάλια
# €85.00
# ONLY AT
# Hoodrich OG Unisex Slides
# €31.00
# ONLY AT
# Hoodrich OG Unisex Slides
# €31.00
# Crocs Bae Clog Γυναικεία Σανδάλια
# €75.00
# Crocs Classic Clog Γυναικεία Σανδάλια
# €59.00
# adidas Originals Adilette 22 Ανδρικά Slides
# €65.00
# Crocs Classic Clog Παιδικά Σανδάλια
# €45.00
# Birkenstock Classic Arizona Ανδρικά Σανδάλια
# €105.00
# Shop Now
# Shop Now
# Shop Now
# Shop Graphic Tees
# Shop adidas Adizero
# Follow Us On Instagram @JDSportsGR
# Share Your Style #MyJDFit
# Follow us
# Join the conversation
# Κέρδισε -10% στην πρώτη σου online παραγγελία άνω των 50€!
# Κάνε sign up για Νέα Drops, Προσφορές & JD News
# Τα στοιχεία σου είναι ασφαλή μαζί μας και θα χρησιμοποιηθούν σύμφωνα με την Πολιτική
# Privacy Notice
# Εφαρμόζονται Όροι Χρήσης
# Shopping with JD
# Καταστήματα & Σημεία Παραλαβής
# Τρόποι Πληρωμής
# Klarna
# BOX NOW
# Ηλεκτρονική Δωροκάρτα
# Εξυπηρέτηση Πελατών
# Επικοινωνία
# Βοήθεια
# Αποστολές & Επιστροφές
# Εταιρεία
# Θέσεις Εργασίας | Αγγελίες
# JD Sports Fashion Plc
# Νομική Χρήση
# Όροι Χρήσης
# Πολιτική Απορρήτου
# Πολιτική Χρήσης Cookies
# Cookie Declaration
# Προσβασιμότητα
# Visit our corporate website at
# www.jdplc.com
# Copyright © 2025 JD Sports All rights reserved.
# Developed by
# Sleed
# .
# We accept the following payment methods
# Αποστολές adidas
# Επιστροφές adidas
# Μετά την καταχώρηση του τεμαχίου, η παραγγελία δεν μπορεί να ακυρωθεί.Η αποστολή από τα κεντρικά της adidas (Γερμανία) γίνεται συνήθως εντός 2 ημερών. Το τεμάχιο εξαιρείται από προωθητικές ενέργειες/κουπόνια/δωροκάρτες.
# Όλες οι επιστροφές adidas είναι εντελώς Δωρεάν. Οι επιστροφές μπορούν να γίνουν εντός 30 ημερών. Οι παραγγελίες adidas συνοδεύονται από έντυπο επιστροφών με αναλυτικές οδηγίες.
# ×
# Διεθνής Παράδοση
# Διαθέσιμη
# If you wish to deliver to
# , please visit JD Sports
# Global
# Go to JD Sports
# Global
# Συνέχισε τις αγορές σου στο JDSports.gr
# Για παραδόσεις εκτός  Ελλάδας, επίλεξε ένα από τα παρακάτω

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT4o have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too. \n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled JDSports.gr | No1 Προορισμός στην Ελλάδα για Premium Sports και Street Fashion
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# My Account ( Login/Signup )
# Καταστήματα
# Βοήθεια
# Πορεία Παραγγελίας
# Αγαπημένα
# Παράδοση σε...
# EL
# EN
# EL
# New In
# Ανδρικά
# Γυναικεία
# Παιδικά
# Αξεσουάρ
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Άνδρας
# Παπούτσια
# New In
# Sneakers
# Slides & Σανδάλια
# Μποτάκια
# Running
# Όλα τα Παπούτσια
# Ρούχα
# New In
# T-shirts & Αμάνικα
# Σορτς & Βερμούδες
# Μαγιό
# Φόρμες & Σετ
# Ζακέτες
# Φούτερ
# Jeans & Cargo Pants
# Μπουφάν
# Όλα τα Ρούχα
# Top Brands
# Nike
# adidas
# Jordan
# Hoodrich
# The North Face
# EA7 Emporio Armani
# New Balance
# McKenzie
# Supply & Demand
# Converse
# Columbia
# Όλα τα brands
# Edits
# 2 T-shirts for 40€
# 2 McKenzie T-shirts for 20€
# Ποδοσφαιρικές Φανέλες
# Graphic Tees
# JD Exclusives
# Λευκά Παπούτσια
# Μαύρα Παπούτσια
# Όλα τα Ανδρικά
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Γυναίκα
# Παπούτσια
# New In
# Sneakers
# Slides & Σανδάλια
# Μποτάκια
# Running
# Γυμναστήριο & Crossfit
# Όλα τα παπούτσια
# Ρούχα
# New In
# T-shirts & Αμάνικα
# Σορτς & Βερμούδες
# Κολάν
# Μπουστάκια
# Μαγιό
# Φόρμες & Σετ
# Φούτερ
# Ζακέτες
# Jeans & Cargo Pants
# Μπουφάν
# Όλα τα Ρούχα
# Top Brands
# Nike
# adidas
# Jordan
# Hoodrich
# New Balance
# The North Face
# Unlike Humans
# UGG
# Converse
# Vans
# PUMA
# Ολα τα brands
# Edits
# JD Exclusives
# Ποδοσφαιρικές Φανέλες
# Graphic Tees
# Λευκά Παπούτσια
# Μαύρα Παπούτσια
# Animal Print
# Gymwear
# Co-Ord Sets
# Όλα τα Γυναικεία
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Παιδί
# Παπούτσια
# New In
# Βρεφικά | No. 19-27
# Παιδικά | No. 28-35
# Εφηβικά | No. 36-40
# Sneakers
# Slides & Σανδάλια
# Μποτάκια
# Running
# Όλα τα Παπούτσια
# Ρούχα
# New In
# T-shirts
# Σορτς & Βερμούδες
# Φόρμες & Σετ Φόρμας
# Μαγιό
# Ζακέτες
# Φούτερ
# Μπουφάν
# Όλα τα Ρούχα
# Αξεσουάρ
# Σακίδια Πλάτης
# Κάλτσες
# Εσώρουχα
# Καπέλα
# Όλα τα Αξεσουαρ
# Ρούχα για Αγόρια
# T-shirts
# Σορτς
# Φόρμες & Σετ Φόρμας
# Ζακέτες
# Φούτερ
# Μπουφάν
# Όλα τα Ρούχα για Αγόρια
# Ρούχα για Κορίτσια
# T-shirts
# Φόρμες & Σετ Φόρμας
# Κολάν
# Φούτερ
# Όλα τα Ρούχα για Κορίτσια
# Top Brands
# Nike
# adidas
# Hoodrich
# Jordan
# Supply & Demand
# McKenzie
# The North Face
# PUMA
# Όλα τα brands
# Edits
# Ποδοσφαιρικές Φανέλες
# JD Exclusives
# Μαύρα Παπούτσια
# Λευκά Παπούτσια
# Best Sellers
# Όλα τα Παιδικά
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
#
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Savings
# Sale
# Outlet
# Smart Buys
# Όλες οι Ευκαιρίες
# Featured
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# eGiftcard
# Πληροφορίες
# Follow Us
# Αναζήτηση
# Trending Now
# >
# Trending Now
# Nike Air Force 1
# JD Exclusive
# Χμμ..  Δεν καταφέραμε να βρούμε αποτελέσματα :/
# Δοκίμασε ξανά! Έλεγξε για λάθη πληκτρολόγησης  (ονομασία ή κωδικό προϊόντος)
# Άδειο Καλάθι
# Κανένα προϊόν
# Δωρεάν Μεταφορικά
# Δωρεάν παραλαβή απο κατάστημα
# Δωρεάν μεταφορικά άνω των 69€
# subtotalVar
# Subtotal
# discountVar
# Έκπτωση
# 0
# Σύνολο
# Ολοκλήρωση Αγοράς
# NIKE AIR MAX 95
# NEW EXCLUSIVE COLOURWAYS
# CROCS SLIDES & SANDALS
# ΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ
# T-SHIRTS & SHORTS
# ΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ
# ΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%!
# JOIN THE FAM'
# Shop Now
# Shop Now
# Shop Now
# Shop Now
# Αγαπημένα Brands
# ΑΝΔΡΙΚΑ
# Ρούχα
# Παπούτσια
# JD Exclusives
# ΓΥΝΑΙΚΕΙΑ
# Ρούχα
# Παπούτσια
# JD Exclusives
# ΠΑΙΔΙΚΑ
# Ρούχα
# Παπούτσια
# JD Exclusives
# Complete The Look
# T-shirts
# Σορτς
# Slides & Σανδάλια
# JUST DROPPED
# ONLY AT
# Hoodrich Galaxy Ανδρικό T-shirt
# €45.00
# JUST DROPPED
# ONLY AT
# Jordan Flight MVP Ανδρικό T-shirt
# €39.99
# JUST DROPPED
# ONLY AT
# adidas Originals Football Ανδρικό T-shirt
# €40.00
# JUST DROPPED
# ONLY AT
# adidas Originals Classic Γυναικείο T-Shirt
# €35.00
# JUST DROPPED
# ONLY AT
# The North Face Energy Γυναικείο T-Shirt
# €40.00
# JUST DROPPED
# Nike Sportswear Essential Γυναικείο T-Shirt
# €34.99
# JUST DROPPED
# ONLY AT
# The North Face Reflective Grid Παιδικό T-shirt
# €30.00
# Nike Boxy Essential Παιδικό T-shirt
# €22.99
# JUST DROPPED
# Nike Training Pro Γυναικείο Σορτς
# €29.99
# JUST DROPPED
# ONLY AT
# adidas Originals Football Γυναικείο Σορτς
# €40.00
# Jordan Diamond Ανδρικό Σορτς
# €49.99
# JUST DROPPED
# ONLY AT
# The North Face 24/7   Ανδρικό Σορτς
# €45.00
# JUST DROPPED
# ONLY AT
# Hoodrich Erupt Γυναικείο Σορτς
# €40.00
# JUST DROPPED
# ONLY AT
# Hoodrich Legacy Ανδρικό Σορτς
# €60.00
# JUST DROPPED
# Nike Pro Παιδικό Σορτς
# €21.50
# ONLY AT
# McKenzie Racer Παιδικό Σορτς
# €16.00
# Crocs Mega Crush Clog Γυναικεία Σανδάλια
# €85.00
# ONLY AT
# Hoodrich OG Unisex Slides
# €31.00
# ONLY AT
# Hoodrich OG Unisex Slides
# €31.00
# Crocs Bae Clog Γυναικεία Σανδάλια
# €75.00
# Crocs Classic Clog Γυναικεία Σανδάλια
# €59.00
# adidas Originals Adilette 22 Ανδρικά Slides
# €65.00
# Crocs Classic Clog Παιδικά Σανδάλια
# €45.00
# Birkenstock Classic Arizona Ανδρικά Σανδάλια
# €105.00
# Shop Now
# Shop Now
# Shop Now
# Shop Graphic Tees
# Shop adidas Adizero
# Follow Us On Instagram @JDSportsGR
# Share Your Style #MyJDFit
# Follow us
# Join the conversation
# Κέρδισε -10% στην πρώτη σου online παραγγελία άνω των 50€!
# Κάνε sign up για Νέα Drops, Προσφορές & JD News
# Τα στοιχεία σου είναι ασφαλή μαζί μας και θα χρησιμοποιηθούν σύμφωνα με την Πολιτική
# Privacy Notice
# Εφαρμόζονται Όροι Χρήσης
# Shopping with JD
# Καταστήματα & Σημεία Παραλαβής
# Τρόποι Πληρωμής
# Klarna
# BOX NOW
# Ηλεκτρονική Δωροκάρτα
# Εξυπηρέτηση Πελατών
# Επικοινωνία
# Βοήθεια
# Αποστολές & Επιστροφές
# Εταιρεία
# Θέσεις Εργασίας | Αγγελίες
# JD Sports Fashion Plc
# Νομική Χρήση
# Όροι Χρήσης
# Πολιτική Απορρήτου
# Πολιτική Χρήσης Cookies
# Cookie Declaration
# Προσβασιμότητα
# Visit our corporate website at
# www.jdplc.com
# Copyright © 2025 JD Sports All rights reserved.
# Developed by
# Sleed
# .
# We accept the following payment methods
# Αποστολές adidas
# Επιστροφές adidas
# Μετά την καταχώρηση του τεμαχίου, η παραγγελία δεν μπορεί να ακυρωθεί.Η αποστολή από τα κεντρικά της adidas (Γερμανία) γίνεται συνήθως εντός 2 ημερών. Το τεμάχιο εξαιρείται από προωθητικές ενέργειες/κουπόνια/δωροκάρτες.
# Όλες οι επιστροφές adidas είναι εντελώς Δωρεάν. Οι επιστροφές μπορούν να γίνουν εντός 30 ημερών. Οι παραγγελίες adidas συνοδεύονται από έντυπο επιστροφών με αναλυτικές οδηγίες.
# ×
# Διεθνής Παράδοση
# Διαθέσιμη
# If you wish to deliver to
# , please visit JD Sports
# Global
# Go to JD Sports
# Global
# Συνέχισε τις αγορές σου στο JDSports.gr
# Για παραδόσεις εκτός  Ελλάδας, επίλεξε ένα από τα παρακάτω

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a snarky assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

# %%
# To give you a preview -- calling OpenAI with system and user messages:

response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh, let me dust off my calculator for this one. Drumroll, please... It's 4! Shocking, I know.

# %% [markdown]
# ## And now let's build useful messages for GPT-4o-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': "You are looking at a website titled JDSports.gr | No1 Προορισμός στην Ελλάδα για Premium Sports και Street Fashion\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nMy Account ( Login/Signup )\nΚαταστήματα\nΒοήθεια\nΠορεία Παραγγελίας\nΑγαπημένα\nΠαράδοση σε...\nEL\nEN\nEL\nNew In\nΑνδρικά\nΓυναικεία\nΠαιδικά\nΑξεσουάρ\nNIKE AIR MAX 95\nNEW EXCLUSIVE COLOURWAYS\nCROCS SLIDES & SANDALS\nΑΝΑΚΑΛΥΨΕ ΤΑ ΤΩΡΑ\nT-SHIRTS & SHORTS\nΑΝΑΝΕΩΣΕ ΤΑ SUMMER 'FITS ΣΟΥ\nΚΑΝΕ ΕΓΓΡΑΦΗ ΚΑΙ ΚΕΡΔΙΣΕ -10%
# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
#display_summary("https://ispania.gr")
display_summary("https://edwarddonner.com")
# Out:
# # Summary of Edward Donner's Website
#
# **Overview:**
# Edward Donner's website serves as a platform for him to share his interests in coding, experimenting with language models (LLMs), and DJing. He is the co-founder and CTO of Nebula.io, which focuses on applying AI to enhance talent discovery and management. Edward has a background as the founder and CEO of the AI startup untapt, which was acquired in 2021.
#
# ## Key Sections:
#
# - **Home:** Introduction to Edward and his interests.
# - **Connect Four:** A feature where LLMs compete in a strategic arena.
# - **Outsmart:** Another initiative related to LLMs.
# - **About:** More personal information about Edward and his professional journey.
# - **Posts:** Blog entries and updates.
#
# ## News & Announcements:
#
# 1. **May 18, 2025:** Announcement for an "AI Executive Briefing".
# 2. **April 21, 2025:** Launch of "The Complete Agentic AI Engineering Course".
# 3. **January 23, 2025:** Workshop titled "LLM Workshop – Hands-on with Agents" with resource sharing.
# 4. **December 21, 2024:** Welcome post addressing "SuperDataScientists".
#
# **Connect:** Users can reach out via email or follow his social media profiles for updates.
#
# **Newsletter:** Option available for visitors to subscribe to receive updates directly.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://csd.uoc.gr")
# Out:
# # Τμήμα Επιστήμης Υπολογιστών - Πανεπιστήμιο Κρήτης
#
# Το Τμήμα Επιστήμης Υπολογιστών του Πανεπιστημίου Κρήτης προσφέρει αξιόλογα προπτυχιακά και μεταπτυχιακά προγράμματα, εστιάζοντας σε θεμελιώδεις και εφαρμοσμένες περιοχές της επιστήμης υπολογιστών. Διεξάγει σημαντική έρευνα και προάγει την επαγγελματική και προσωπική ανάπτυξη των φοιτητών μέσω εργαστηρίων και εκπαιδευτικών δραστηριοτήτων.
#
# ## Νέα και Ανακοινώσεις
#
# - **Times Higher Education 2025:** Το Τμήμα Επιστήμης Υπολογιστών του Πανεπιστημίου Κρήτης κατέκτησε την 1η θέση στην Ελλάδα!
#   - **Ημερομηνία:** 19/02/2025
#
# - **Διακεκριμένη Ομιλία:** Video quality optimization in adaptive streaming από τον Dr. Ioannis Katsavounidis (Meta).
#   - **Ημερομηνία:** 16/05/2025
#
# - **Ανακοίνωση Υποτροφίας Κληροδοτήματος “Μαρίας Μιχαήλ Μανάσση 2023-24.**
#   - **Ημερομηνία:** 14/05/2025
#
# - **Πρακτική Άσκηση μέσω ΕΣΠΑ:** Ανακοίνωση για υποβολή αιτήσεων.
#   - **Ημερομηνία:** 20/05/2025
#
# - **Προκήρυξη Εκλογών:** Για την ανάδειξη Προέδρου και Αντιπροέδρου του Τμήματος.
#   - **Ημερομηνία:** 13/05/2025
#
# Για περισσότερες πληροφορίες και λεπτομέρειες, επισκεφτείτε τον ιστότοπο του τμήματος.

# %% [markdown]
# display_summary("https://anthropic.com")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

#system_prompt = "είσαι ένα σύστημα που δημιουργεί τίτλο από ένα μήνυμα ηλεκτρονικού ταχυδρομείου"
#system_prompt = "είσαι ένα σύστημα που αναλύει μήνυμα ηλεκτρονικού ταχυδρομείου και βρίσκει τις πόλεις και τις χώρες στο ταξίδι"
system_prompt = "είσαι ένα σύστημα που απαντάει σε ερωτήσεις για βιογραφικό με φιλικό τρόπο"
#system_prompt = "είσαι ένα σύστημα που φτιάχνει ποιήματα από ένα μήνυμα email"
user_prompt = """
Παρακάτω ακολουθεί το βιογραφικό και πρέπει να απαντάς σε ερωτήσεις.
Τι γλώσσες ξέρει;


Viktoria Miliaraki
Semelis 3, Heraklion, Crete | (+30)6900034752 | vickymilkon@gmail.com |
www.linkedin.com/in/viktoria-miliaraki-b99096360
Profile
Undergraduate Computer Science student at the University of Crete with strong foundations in software
engineering, systems programming, and algorithmic thinking. Known for being consistent, patient,
responsible and hard-working, with a strong determination to meet and exceed any requirements given.
Passionate about problem-solving and continuous learning, I thrive both independently and in team
environments and am eager to apply my academic knowledge through an internship.
Education
Undergraduate student at the Computer Science department in University of Crete.
Additional Experience
Erasmus+ Youth Exchange Participant:
Middle School: Italy, 2017
High school: Norway, 2018
Participated in school exchange programs focused on intercultural learning and collaborative educational
activities. Developed teamwork, communication, and adaptability through international group projects.
Projects
Custom Compiler (C)
Developed a full pipeline including lexical and syntax analysis, intermediate code generation,
and virtual machine implementation.
MicroTCP Protocol Implementation (C)
Implemented a simplified TCP-like protocol focusing on reliable transmission, handshakes,
and windowing.
Publish-Subscribe Messaging System (C)
Designed a message-broker system using both lists and a binary search tree to manage topics
and subscribers.
AI Pacman Game (Python)
Built intelligent agents using A*, Minimax, AB pruning and other algorithms to play Pacman
effectively.
Stratego Game (Java)
Simulated a full Stratego board game with GUI.
Pet Care Management System
Web application using Java and SQL (backend), JavaScript, and HTML/CSS for UI.
Car Rental System
Full-stack project with Java AND SQL backend and a dynamic web front-end in JS, HTML/CSS.
Graph Analysis of AI Trends (Python)
Used NetworkX to analyze trends in AI adoption via structured dataset and network metrics
Skills & Abilities
Languages:
- Greek
- English (Proficiency Certificate (ECPE) – C2)
Programming languages I’ve worked with: C, C++, Java, JavaScript, SQL, Python, Scala, Assembly
Tools & Technologies: Git, VSCode, Eclipse, IntelliJ, Netbeans, NetworkX, Node.js, Matlab
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Η Βικτώρια ξέρει δύο γλώσσες: Ελληνικά και Αγγλικά, με επίπεδο Αγγλικών πολύ καλό (Proficiency Certificate – C2). Αν θέλεις, μπορώ να σου πω και για τις γλώσσες προγραμματισμού που έχει δει! Θες;

# %%
print(user_prompt)
# Out:
# Παρακάτω ακολουθεί το βιογραφικό και πρέπει να απαντάς σε ερωτήσεις.
# Τι γλώσσες ξέρει;
#
#
# Viktoria Miliaraki
# Semelis 3, Heraklion, Crete | (+30)6900034752 | vickymilkon@gmail.com |
# www.linkedin.com/in/viktoria-miliaraki-b99096360
# Profile
# Undergraduate Computer Science student at the University of Crete with strong foundations in software
# engineering, systems programming, and algorithmic thinking. Known for being consistent, patient,
# responsible and hard-working, with a strong determination to meet and exceed any requirements given.
# Passionate about problem-solving and continuous learning, I thrive both independently and in team
# environments and am eager to apply my academic knowledge through an internship.
# Education
# Undergraduate student at the Computer Science department in University of Crete.
# Additional Experience
# Erasmus+ Youth Exchange Participant:
# Middle School: Italy, 2017
# High school: Norway, 2018
# Participated in school exchange programs focused on intercultural learning and collaborative educational
# activities. Developed teamwork, communication, and adaptability through international group projects.
# Projects
# Custom Compiler (C)
# Developed a full pipeline including lexical and syntax analysis, intermediate code generation,
# and virtual machine implementation.
# MicroTCP Protocol Implementation (C)
# Implemented a simplified TCP-like protocol focusing on reliable transmission, handshakes,
# and windowing.
# Publish-Subscribe Messaging System (C)
# Designed a message-broker system using both lists and a binary search tree to manage topics
# and subscribers.
# AI Pacman Game (Python)
# Built intelligent agents using A*, Minimax, AB pruning and other algorithms to play Pacman
# effectively.
# Stratego Game (Java)
# Simulated a full Stratego board game with GUI.
# Pet Care Management System
# Web application using Java and SQL (backend), JavaScript, and HTML/CSS for UI.
# Car Rental System
# Full-stack project with Java AND SQL backend and a dynamic web front-end in JS, HTML/CSS.
# Graph Analysis of AI Trends (Python)
# Used NetworkX to analyze trends in AI adoption via structured dataset and network metrics
# Skills & Abilities
# Languages:
# - Greek
# - English (Proficiency Certificate (ECPE) – C2)
# Programming languages I’ve worked with: C, C++, Java, JavaScript, SQL, Python, Scala, Assembly
# Tools & Technologies: Git, VSCode, Eclipse, IntelliJ, Netbeans, NetworkX, Node.js, Matlab

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %%
user_prompt
# Out:
# '\nΠαρακάτω ακολουθεί το βιογραφικό και πρέπει να απαντάς σε ερωτήσεις.\nΤι γλώσσες ξέρει;\n\n\nViktoria Miliaraki\nSemelis 3, Heraklion, Crete | (+30)6900034752 | vickymilkon@gmail.com |\nwww.linkedin.com/in/viktoria-miliaraki-b99096360\nProfile\nUndergraduate Computer Science student at the University of Crete with strong foundations in software\nengineering, systems programming, and algorithmic thinking. Known for being consistent, patient,\nresponsible and hard-working, with a strong determination to meet and exceed any requirements given.\nPassionate about problem-solving and continuous learning, I thrive both independently and in team\nenvironments and am eager to apply my academic knowledge through an internship.\nEducation\nUndergraduate student at the Computer Science department in University of Crete.\nAdditional Experience\nErasmus+ Youth Exchange Participant:\nMiddle School: Italy, 2017\nHigh school: Norway, 2018\nParticipated in school exchange programs focused on intercultural learning and collaborative educational\nactivities. Developed teamwork, communication, and adaptability through international group projects.\nProjects\nCustom Compiler (C)\nDeveloped a full pipeline including lexical and syntax analysis, intermediate code generation,\nand virtual machine implementation.\nMicroTCP Protocol Implementation (C)\nImplemented a simplified TCP-like protocol focusing on reliable transmission, handshakes,\nand windowing.\nPublish-Subscribe Messaging System (C)\nDesigned a message-broker system using both lists and a binary search tree to manage topics\nand subscribers.\nAI Pacman Game (Python)\nBuilt intelligent agents using A*, Minimax, AB pruning and other algorithms to play Pacman\neffectively.\nStratego Game (Java)\nSimulated a full Stratego board game with GUI.\nPet Care Management System\nWeb application using Java and SQL (backend), JavaScript, and HTML/CSS for UI.\nCar Rental System\nFull-stack project with Java AND SQL backend and a dynamic web front-end in JS, HTML/CSS.\nGraph Analysis of AI Trends (Python)\nUsed NetworkX to analyze trends in AI adoption via structured dataset and network metrics\nSkills & Abilities\nLanguages:\n- Greek\n- English (Proficiency Certificate (ECPE) – C2)\nProgramming languages I’ve worked with: C, C++, Java, JavaScript, SQL, Python, Scala, Assembly\nTools & Technologies: Git, VSCode, Eclipse, IntelliJ, Netbeans, NetworkX, Node.js, Matlab\n'

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then GPT has given some nice instructions on how to submit a Pull Request. It's a bit of an involved process, but once you've done it once it's pretty clear. As a pro-tip: it's best if you clear the outputs of your Jupyter notebooks (Edit >> Clean outputs of all cells, and then Save) for clean notebooks.
#
# Here are good instructions courtesy of an AI friend:
# https://chatgpt.com/share/677a9cb5-c64c-8012-99e0-e06e88afd293
